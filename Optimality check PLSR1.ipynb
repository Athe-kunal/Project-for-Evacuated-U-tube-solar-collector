# %%
import import_ipynb
import All_in_One
import itertools
import numpy as np
from termcolor import colored
import pandas as pd
# Out:
# importing Jupyter notebook from All_in_One.ipynb

# %%
# temperature = [26,34]
# intensity = [0.52,1.08]
# inlet_temp = [23,38]
# flow_rate = [6,24]

# s = []
# s.append(temperature)
# s.append(intensity)
# s.append(inlet_temp)
# s.append(flow_rate)

# combined_list = list(itertools.product(*s))

# %%
temp = [*range(26,35,1)]
inte = [i/100 for i in range(52,109,1)]

inlet = [*range(23,39,1)]
fr = [*range(6,25,1)]

s = []
s.append(temp)
s.append(inte)
s.append(inlet)
s.append(fr)

combined_list = list(itertools.product(*s))
# combined_list

# %%
class optimality_check:
    def __init__(self,case,output):
        self.output = output
        self.case = case
        self.check()
    
    def get_model(self):
        model_name = All_in_One.All_in_one(self.case,'plsr1',self.output,2)
        predictions,y_val,r2_scores,model,error = model_name.train_model()
        return model
    
    def create_dataframe(self,list_):
        
        init = []
        vals = []
        for i,j in list_:
            init.append(i)
            vals.append(j)
        d = {"Initial parameters":init,"Optimal Values":vals}
        df = pd.DataFrame(data=d)
        return df
    
    def check(self):
        preds = []
        values = []
        model = self.get_model()
        for i in combined_list:
            np_i = np.array(i)
            pred = model.predict(np_i.reshape(1,-1))
            preds.append(list(pred[0]))
            values.append(list(np_i))
        max_val = max(preds)
        init_val = []
        list_ = list(zip(values,preds))
        for i,j in list_:
            if j == max_val:
                print(colored(i,"red"))
                print(colored(j,"green"))
                df = self.create_dataframe(list_)
                print(df)

# %%
heat_c1 = optimality_check("c1",'heat')
# Out:
# {1: 0.9918420171825205, 2: 0.9918420171825205, 3: 0.9918420171825205, 4: 0.9918420171825205}
# Number of prinicipal components for c1 heat is 4
# (4, 4)
# [34.0, 1.08, 23.0, 24.0]
# [0.32373785570056746]
#               Initial parameters         Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]  [0.13487093184527052]
# 1        [26.0, 0.52, 23.0, 7.0]   [0.1403767479675968]
# 2        [26.0, 0.52, 23.0, 8.0]   [0.1458825640899231]
# 3        [26.0, 0.52, 23.0, 9.0]  [0.15138838021224937]
# 4       [26.0, 0.52, 23.0, 10.0]  [0.15689419633457563]
# ...                          ...                    ...
# 155947  [34.0, 1.08, 38.0, 20.0]   [0.2851102509089886]
# 155948  [34.0, 1.08, 38.0, 21.0]   [0.2906160670313149]
# 155949  [34.0, 1.08, 38.0, 22.0]   [0.2961218831536412]
# 155950  [34.0, 1.08, 38.0, 23.0]  [0.30162769927596744]
# 155951  [34.0, 1.08, 38.0, 24.0]   [0.3071335153982937]
#
# [155952 rows x 2 columns]

# %%
eff_c1 = optimality_check("c1",'efficiency')
# Out:
# {1: 0.9571752730809749, 2: 0.9571752730809749, 3: 0.9571752730809749, 4: 0.9571752730809749}
# Number of prinicipal components for c1 efficiency is 4
# (3, 4)
# [34.0, 0.52, 23.0, 24.0]
# [0.9890146834194625]
#               Initial parameters        Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]  [0.6576111484220498]
# 1        [26.0, 0.52, 23.0, 7.0]  [0.6745231661762982]
# 2        [26.0, 0.52, 23.0, 8.0]  [0.6914351839305466]
# 3        [26.0, 0.52, 23.0, 9.0]  [0.7083472016847949]
# 4       [26.0, 0.52, 23.0, 10.0]  [0.7252592194390433]
# ...                          ...                   ...
# 155947  [34.0, 1.08, 38.0, 20.0]  [0.7103699338364431]
# 155948  [34.0, 1.08, 38.0, 21.0]  [0.7272819515906914]
# 155949  [34.0, 1.08, 38.0, 22.0]  [0.7441939693449398]
# 155950  [34.0, 1.08, 38.0, 23.0]  [0.7611059870991881]
# 155951  [34.0, 1.08, 38.0, 24.0]  [0.7780180048534365]
#
# [155952 rows x 2 columns]

# %%
heat_c2 = optimality_check("c2","heat")
# Out:
# {1: 0.9784501386479055, 2: 0.9784501386479055, 3: 0.9784501386479055, 4: 0.9784501386479055}
# Number of prinicipal components for c2 heat is 4
# (4, 4)
# [34.0, 1.08, 23.0, 24.0]
# [0.9051145415915329]
#               Initial parameters         Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]  [0.41640765444171773]
# 1        [26.0, 0.52, 23.0, 7.0]   [0.4300550616427451]
# 2        [26.0, 0.52, 23.0, 8.0]   [0.4437024688437724]
# 3        [26.0, 0.52, 23.0, 9.0]   [0.4573498760447997]
# 4       [26.0, 0.52, 23.0, 10.0]  [0.47099728324582707]
# ...                          ...                    ...
# 155947  [34.0, 1.08, 38.0, 20.0]   [0.8293007993806499]
# 155948  [34.0, 1.08, 38.0, 21.0]   [0.8429482065816772]
# 155949  [34.0, 1.08, 38.0, 22.0]   [0.8565956137827045]
# 155950  [34.0, 1.08, 38.0, 23.0]    [0.870243020983732]
# 155951  [34.0, 1.08, 38.0, 24.0]   [0.8838904281847593]
#
# [155952 rows x 2 columns]

# %%
eff_c2 = optimality_check('c2','efficiency')
# Out:
# {1: 0.9571752730809749, 2: 0.9571752730809749, 3: 0.9571752730809749, 4: 0.9571752730809749}
# Number of prinicipal components for c2 efficiency is 4
# (3, 4)
# [34.0, 0.52, 23.0, 24.0]
# [0.9890146834194625]
#               Initial parameters        Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]  [0.6576111484220498]
# 1        [26.0, 0.52, 23.0, 7.0]  [0.6745231661762982]
# 2        [26.0, 0.52, 23.0, 8.0]  [0.6914351839305466]
# 3        [26.0, 0.52, 23.0, 9.0]  [0.7083472016847949]
# 4       [26.0, 0.52, 23.0, 10.0]  [0.7252592194390433]
# ...                          ...                   ...
# 155947  [34.0, 1.08, 38.0, 20.0]  [0.7103699338364431]
# 155948  [34.0, 1.08, 38.0, 21.0]  [0.7272819515906914]
# 155949  [34.0, 1.08, 38.0, 22.0]  [0.7441939693449398]
# 155950  [34.0, 1.08, 38.0, 23.0]  [0.7611059870991881]
# 155951  [34.0, 1.08, 38.0, 24.0]  [0.7780180048534365]
#
# [155952 rows x 2 columns]
