# %%
import import_ipynb
import All_in_One
import itertools
import numpy as np
from termcolor import colored
import pandas as pd
# Out:
# importing Jupyter notebook from All_in_One.ipynb

# %%
# temperature = [26,34]
# intensity = [0.52,1.08]
# inlet_temp = [23,38]
# flow_rate = [6,24]

# s = []
# s.append(temperature)
# s.append(intensity)
# s.append(inlet_temp)
# s.append(flow_rate)

# combined_list = list(itertools.product(*s))

# %%
temp = [*range(26,35,1)]
inte = [i/100 for i in range(52,109,1)]

inlet = [*range(23,39,1)]
fr = [*range(6,25,1)]

s = []
s.append(temp)
s.append(inte)
s.append(inlet)
s.append(fr)

combined_list = list(itertools.product(*s))
# combined_list

# %%
class optimality_check:
    def __init__(self,case,output):
        self.output = output
        self.case = case
        self.check()
    
    def get_model(self):
        model_name = All_in_One.All_in_one(self.case,'pca',self.output,2)
        predictions,y_val,r2_scores,model,error = model_name.train_model()
        return model
    
    def create_dataframe(self,list_):
        
        init = []
        vals = []
        for i,j in list_:
            init.append(i)
            vals.append(j)
        d = {"Initial parameters":init,"Optimal Values":vals}
        df = pd.DataFrame(data=d)
        return df
    
    def check(self):
        preds = []
        values = []
        model = self.get_model()
        for i in combined_list:
            np_i = np.array(i)
            pred = model.predict(np_i.reshape(1,-1))
            preds.append(list(pred))
            values.append(list(np_i))
        max_val = max(preds)
        init_val = []
        list_ = list(zip(values,preds))
        for i,j in list_:
            if j == max_val:
                print(colored(i,"red"))
                print(colored(j,"green"))
                df = self.create_dataframe(list_)
                print(df)

# %%
heat_c1 = optimality_check("c1",'heat')
# Out:
# {1: 0.6659679333794485, 2: 0.880621244001276, 3: 0.8656522859940343, 4: 0.9908649287669715}
# Number of prinicipal components for c1 heat is 4
# (4, 4)
# [34.0, 1.08, 23.0, 24.0]
# [0.32365994970928813]
#               Initial parameters         Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]  [0.13483226131693615]
# 1        [26.0, 0.52, 23.0, 7.0]  [0.14032069141856726]
# 2        [26.0, 0.52, 23.0, 8.0]  [0.14580912152019837]
# 3        [26.0, 0.52, 23.0, 9.0]  [0.15129755162182945]
# 4       [26.0, 0.52, 23.0, 10.0]  [0.15678598172346056]
# ...                          ...                    ...
# 155947  [34.0, 1.08, 38.0, 20.0]  [0.28505379479921217]
# 155948  [34.0, 1.08, 38.0, 21.0]  [0.29054222490084325]
# 155949  [34.0, 1.08, 38.0, 22.0]   [0.2960306550024744]
# 155950  [34.0, 1.08, 38.0, 23.0]   [0.3015190851041055]
# 155951  [34.0, 1.08, 38.0, 24.0]  [0.30700751520573655]
#
# [155952 rows x 2 columns]

# %%
eff_c1 = optimality_check("c1",'efficiency')
# Out:
# {1: 0.6994358010638175, 2: 0.9679452925902645, 3: 0.949442191461532, 4: 0.9546678731186268}
# Number of prinicipal components for c1 efficiency is 4
# (3, 4)
# [34.0, 0.52, 23.0, 24.0]
# [0.8937816847189953]
#               Initial parameters        Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]  [0.5843996559899586]
# 1        [26.0, 0.52, 23.0, 7.0]  [0.6011575106707151]
# 2        [26.0, 0.52, 23.0, 8.0]  [0.6179153653514717]
# 3        [26.0, 0.52, 23.0, 9.0]  [0.6346732200322283]
# 4       [26.0, 0.52, 23.0, 10.0]  [0.6514310747129849]
# ...                          ...                   ...
# 155947  [34.0, 1.08, 38.0, 20.0]  [0.7776953353657853]
# 155948  [34.0, 1.08, 38.0, 21.0]  [0.7944531900465418]
# 155949  [34.0, 1.08, 38.0, 22.0]  [0.8112110447272984]
# 155950  [34.0, 1.08, 38.0, 23.0]   [0.827968899408055]
# 155951  [34.0, 1.08, 38.0, 24.0]  [0.8447267540888115]
#
# [155952 rows x 2 columns]

# %%
heat_c2 = optimality_check("c2","heat")
# Out:
# {1: 0.6457738529023811, 2: 0.8513718712597533, 3: 0.6729144906053033, 4: 0.974269986942737}
# Number of prinicipal components for c2 heat is 4
# (4, 4)
# [34.0, 1.08, 23.0, 24.0]
# [0.9074606263998941]
#               Initial parameters         Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]   [0.4150938015283942]
# 1        [26.0, 0.52, 23.0, 7.0]    [0.429067805804179]
# 2        [26.0, 0.52, 23.0, 8.0]   [0.4430418100799638]
# 3        [26.0, 0.52, 23.0, 9.0]  [0.45701581435574856]
# 4       [26.0, 0.52, 23.0, 10.0]   [0.4709898186315334]
# ...                          ...                    ...
# 155947  [34.0, 1.08, 38.0, 20.0]   [0.8332916072252086]
# 155948  [34.0, 1.08, 38.0, 21.0]   [0.8472656115009933]
# 155949  [34.0, 1.08, 38.0, 22.0]   [0.8612396157767782]
# 155950  [34.0, 1.08, 38.0, 23.0]    [0.875213620052563]
# 155951  [34.0, 1.08, 38.0, 24.0]   [0.8891876243283477]
#
# [155952 rows x 2 columns]

# %%
eff_c2 = optimality_check('c2','efficiency')
# Out:
# {1: 0.6994358010638175, 2: 0.9679452925902645, 3: 0.949442191461532, 4: 0.9546678731186268}
# Number of prinicipal components for c2 efficiency is 4
# (3, 4)
# [34.0, 0.52, 23.0, 24.0]
# [0.8937816847189953]
#               Initial parameters        Optimal Values
# 0        [26.0, 0.52, 23.0, 6.0]  [0.5843996559899586]
# 1        [26.0, 0.52, 23.0, 7.0]  [0.6011575106707151]
# 2        [26.0, 0.52, 23.0, 8.0]  [0.6179153653514717]
# 3        [26.0, 0.52, 23.0, 9.0]  [0.6346732200322283]
# 4       [26.0, 0.52, 23.0, 10.0]  [0.6514310747129849]
# ...                          ...                   ...
# 155947  [34.0, 1.08, 38.0, 20.0]  [0.7776953353657853]
# 155948  [34.0, 1.08, 38.0, 21.0]  [0.7944531900465418]
# 155949  [34.0, 1.08, 38.0, 22.0]  [0.8112110447272984]
# 155950  [34.0, 1.08, 38.0, 23.0]   [0.827968899408055]
# 155951  [34.0, 1.08, 38.0, 24.0]  [0.8447267540888115]
#
# [155952 rows x 2 columns]
